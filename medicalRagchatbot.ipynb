# %%
pip install langchain langchain_community langchain_huggingface faiss_cpu sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 41.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.2/412.2 kB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.29
#     Uninstalling langchain-core-0.3.29:
#       Successfully uninstalled langchain-core-0.3.29
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.14
#     Uninstalling langchain-0.3.14:
#       Successfully uninstalled langchain-0.3.14
# ...

# %%
pip install langchain

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain_community.document_loaders import PyPDFLoader,DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
def load_file(data):
  loader=DirectoryLoader(data,glob="*.pdf",loader_cls=PyPDFLoader)
  documents=loader.load()
  return documents

# %%
pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 7.9 MB/s eta 0:00:00
# ...

# %%
path="/content/drive/MyDrive/temp files/"
doc=load_file(path)
print(len(doc))
# Out:
# 759

# %%
def create_chunks(data):
  text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
  chunks=text_splitter.split_documents(data)
  return chunks

doc_chunks=create_chunks(doc)

# %%
def get_embeddings():
  embeddings=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
  return embeddings

embed=get_embeddings()

# %%
Faiss_db='db'
db=FAISS.from_documents(doc_chunks,embed)
db.save_local(Faiss_db)

# %%
 from langchain_huggingface import HuggingFaceEndpoint
 from langchain.chains import RetrievalQA
 from langchain_core.prompts import PromptTemplate
 from langchain.embeddings import HuggingFaceEmbeddings

# %%
repoidhugg="mistralai/Mistral-7B-Instruct-v0.3"
# repoidhugg="epfl-llm/meditron-70b"


def load_llm(repoidhugg):
  llm=HuggingFaceEndpoint(repo_id=repoidhugg,
                          temperature=0.5,
                          model_kwargs={"token":token,"max_tokens":2000})
  return llm

llm=load_llm(repoidhugg)

# %%
prompt="""
use the context that has been provided for user's question.
if you dont know the answer just say i dont know dont make up answer.
dont provied anything out of the given context
Context:{context}
Question:{question}

just answer directly
"""

# %%
db

# %%
def set_prompt(prompt):
  prompt_template=PromptTemplate(template=prompt,input_variables=['context','question'])
  return prompt_template

prompt_template=set_prompt(prompt)

# %% [markdown]
# we have the db, dont need to load it again

# %%
qa=RetrievalQA.from_chain_type(llm=llm,
                              chain_type="stuff",
                              retriever=db.as_retriever(search_kwargs={'k':2}),
                              return_source_documents=True,
                              chain_type_kwargs={'prompt':prompt_template})

# %%
# prompt: login to huggingface

from huggingface_hub import login

# Replace with your actual Hugging Face token
# You can find your token in your Hugging Face account settings
token = userdata.get('HF_TOKEN')

login(token=token)

# %%
user_query=input("write query : ")
response=qa.invoke(user_query)
print(response["result"])
print("--------"*4)
if response["source_documents"]:
  print(response["source_documents"])
# Out:
# write query : how to cure headache
# Answer: Treatment for headaches can include prophylactic treatments such as induction and maintenance therapies, which are aimed at preventing headaches, and symptomatic therapy, which is meant to stop or shorten a headache. Some specific treatments mentioned include vitamin C, quercetin, bromelain, essential fatty acids (EFA), adjustments of the spine, craniosacral treatment, massage at the temporomandibular joint (TMJ), and traditional Chinese medical therapies.
# --------------------------------
# ...

# %%
# %%writefile app.py
# Out:
# Writing app.py

# %%
pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 72.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 116.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.9 MB/s eta 0:00:00
# ...

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 34.16.156.40

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹⠸
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.156.40:8501
#
# ⠼⠴⠦your url is: https://sour-bottles-lead.loca.lt
# /content/app.py:6: LangChainDeprecationWarning: Importing HuggingFaceEmbeddings from langchain.embeddings is deprecated. Please replace deprecated imports:
#
# >> from langchain.embeddings import HuggingFaceEmbeddings
#
# with new imports of:
#
# >> from langchain_community.embeddings import HuggingFaceEmbeddings
# You can use the langchain cli to **automatically** upgrade many imports. Please see documentation here <https://python.langchain.com/docs/versions/v0_2/>
#   from langchain.embeddings import HuggingFaceEmbeddings
# 2025-01-22 13:15:53.801 Uncaught app execution
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py", line 88, in exec_func_with_error_handling
# ...
